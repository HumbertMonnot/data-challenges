# %% [markdown]
# # Multiple files with `pandas`

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## Merge Practice

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### Inner Merge Practice

# %%
inner_merged_df = pd.merge(a_df, b_df)
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 2 items
#
# tests/test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED [ 50%]
# tests/test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Left Merge Practice

# %%
left_merged_df = a_df.merge(b_df, on = "Country", how ='left')
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 2 items
#
# tests/test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED [ 50%]
# tests/test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED   [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Right Merge Practice

# %%
right_merged_df = a_df.merge(b_df, on = "Country", how ='right')
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 2 items
#
# tests/test_right_merge.py::TestRightMerge::test_right_merged_df_shape PASSED [ 50%]
# tests/test_right_merge.py::TestRightMerge::test_right_merged_nulls PASSED [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/right_merge.pickle
#
# git commit -m 'Completed right_merge step'
#
# git push origin master

# %% [markdown]
# ### Outer Merge Practice

# %%
outer_merged_df = a_df.merge(b_df, on = "Country", how ='outer')
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 2 items
#
# tests/test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED [ 50%]
# tests/test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Practice

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %% [markdown]
# ## Concat Practice

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %%
file1 = "dictionary.csv"
file2 = "summer.csv"
file3 = "winter.csv"

countries_df = pd.read_csv(file1, decimal=",")
summer_df = pd.read_csv(file2, decimal=",")
winter_df = pd.read_csv(file3, decimal=",")

# %%
countries_df.head(5)
# Out:
#            Country Code  Population    GDP per Capita
# 0      Afghanistan  AFG  32526562.0  594.323081219966
# 1          Albania  ALB   2889167.0  3945.21758150914
# 2          Algeria  ALG  39666519.0  4206.03123244958
# 3  American Samoa*  ASA     55538.0               NaN
# 4          Andorra  AND     70473.0               NaN

# %%
winter_df.head(5)
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
summer_df.rename(columns={"Country":"Code"}, inplace=True)
summer_df["Code"].isnull().sum()
# Out:
# 4

# %%
winter_df.rename(columns={"Country":"Code"}, inplace=True)
winter_df['Code'].unique()
# Out:
# array(['FRA', 'SUI', 'FIN', 'BEL', 'GBR', 'SWE', 'CAN', 'USA', 'AUT',
#        'NOR', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'URS', 'EUA',
#        'JPN', 'POL', 'PRK', 'ROU', 'GDR', 'ESP', 'LIE', 'BUL', 'YUG',
#        'EUN', 'KOR', 'CHN', 'LUX', 'NZL', 'RUS', 'UKR', 'BLR', 'AUS',
#        'SLO', 'KAZ', 'UZB', 'DEN', 'CZE', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %% [markdown]
# ### Combining The Data

# %%
summer_countries_df = summer_df.merge(countries_df, on = "Code", how= "inner")
summer_countries_df["Season"]="Summer"
summer_countries_df
# Out:
#        Year    City      Sport Discipline           Athlete Code Gender  \
# 0      1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1      1896  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2      1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3      1896  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4      1896  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
# ...     ...     ...        ...        ...               ...  ...    ...
# 25737  2012  London  Athletics  Athletics   BARRONDO, Erick  GUA    Men
# 25738  2012  London  Athletics  Athletics     JAMES, Kirani  GRN    Men
# 25739  2012  London  Athletics  Athletics       AMOS, Nijel  BOT    Men
# 25740  2012  London    Sailing    Sailing  KONTIDES, Pavlos  CYP    Men
# 25741  2012  London  Taekwondo  Taekwondo    OBAME, Anthony  GAB    Men
#
#                  Event   Medal    Country  Population    GDP per Capita  \
# 0       100M Freestyle    Gold    Hungary   9844686.0  12363.5434596539
# 1      1200M Freestyle    Gold    Hungary   9844686.0  12363.5434596539
# 2                 100M  Bronze    Hungary   9844686.0  12363.5434596539
# 3                 800M  Silver    Hungary   9844686.0  12363.5434596539
# 4             Marathon  Bronze    Hungary   9844686.0  12363.5434596539
# ...                ...     ...        ...         ...               ...
# 25737        20KM Walk  Silver  Guatemala  16342897.0  3903.47885604613
# 25738             400M    Gold    Grenada    106825.0  9212.02035173484
# 25739             800M  Silver   Botswana   2262485.0  6360.13822018837
# 25740            Laser  Silver     Cyprus   1165300.0  23242.8400685313
# 25741          + 80 KG  Silver      Gabon   1725292.0   8266.4456050624
#
#        Season
# 0      Summer
# 1      Summer
# 2      Summer
# 3      Summer
# 4      Summer
# ...       ...
# 25737  Summer
# 25738  Summer
# 25739  Summer
# 25740  Summer
# 25741  Summer
#
# [25742 rows x 13 columns]

# %%
winter_countries_df = winter_df.merge(countries_df, on = "Code", how= "inner")
winter_countries_df["Season"]="Winter"
winter_countries_df
# Out:
#       Year       City     Sport Discipline              Athlete Code Gender  \
# 0     1924   Chamonix  Biathlon   Biathlon          BERTHET, G.  FRA    Men
# 1     1924   Chamonix  Biathlon   Biathlon       MANDRILLON, C.  FRA    Men
# 2     1924   Chamonix  Biathlon   Biathlon  MANDRILLON, Maurice  FRA    Men
# 3     1924   Chamonix  Biathlon   Biathlon      VANDELLE, André  FRA    Men
# 4     1924   Chamonix   Curling    Curling          ALDEERT, H.  FRA    Men
# ...    ...        ...       ...        ...                  ...  ...    ...
# 4821  2006      Turin    Skiing  Snowboard      ZIDEK, Radoslav  SVK    Men
# 4822  2010  Vancouver  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
# 4823  2010  Vancouver  Biathlon   Biathlon        HURAJT, Pavol  SVK    Men
# 4824  2010  Vancouver  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
# 4825  2014      Sochi  Biathlon   Biathlon   KUZMINA, Anastazia  SVK  Women
#
#                 Event   Medal   Country  Population    GDP per Capita  Season
# 0     Military Patrol  Bronze    France  66808385.0  36205.5681017036  Winter
# 1     Military Patrol  Bronze    France  66808385.0  36205.5681017036  Winter
# 2     Military Patrol  Bronze    France  66808385.0  36205.5681017036  Winter
# 3     Military Patrol  Bronze    France  66808385.0  36205.5681017036  Winter
# 4             Curling  Bronze    France  66808385.0  36205.5681017036  Winter
# ...               ...     ...       ...         ...               ...     ...
# 4821  Snowboard Cross  Silver  Slovakia   5424050.0  16088.2775872723  Winter
# 4822     10KM Pursuit  Silver  Slovakia   5424050.0  16088.2775872723  Winter
# 4823  15KM Mass Start  Bronze  Slovakia   5424050.0  16088.2775872723  Winter
# 4824            7.5KM    Gold  Slovakia   5424050.0  16088.2775872723  Winter
# 4825            7.5KM    Gold  Slovakia   5424050.0  16088.2775872723  Winter
#
# [4826 rows x 13 columns]

# %%
all_df = pd.concat([winter_countries_df, summer_countries_df], axis="index", sort=False)
all_df
# Out:
#        Year      City      Sport Discipline              Athlete Code Gender  \
# 0      1924  Chamonix   Biathlon   Biathlon          BERTHET, G.  FRA    Men
# 1      1924  Chamonix   Biathlon   Biathlon       MANDRILLON, C.  FRA    Men
# 2      1924  Chamonix   Biathlon   Biathlon  MANDRILLON, Maurice  FRA    Men
# 3      1924  Chamonix   Biathlon   Biathlon      VANDELLE, André  FRA    Men
# 4      1924  Chamonix    Curling    Curling          ALDEERT, H.  FRA    Men
# ...     ...       ...        ...        ...                  ...  ...    ...
# 25737  2012    London  Athletics  Athletics      BARRONDO, Erick  GUA    Men
# 25738  2012    London  Athletics  Athletics        JAMES, Kirani  GRN    Men
# 25739  2012    London  Athletics  Athletics          AMOS, Nijel  BOT    Men
# 25740  2012    London    Sailing    Sailing     KONTIDES, Pavlos  CYP    Men
# 25741  2012    London  Taekwondo  Taekwondo       OBAME, Anthony  GAB    Men
#
#                  Event   Medal    Country  Population    GDP per Capita  \
# 0      Military Patrol  Bronze     France  66808385.0  36205.5681017036
# 1      Military Patrol  Bronze     France  66808385.0  36205.5681017036
# 2      Military Patrol  Bronze     France  66808385.0  36205.5681017036
# 3      Military Patrol  Bronze     France  66808385.0  36205.5681017036
# 4              Curling  Bronze     France  66808385.0  36205.5681017036
# ...                ...     ...        ...         ...               ...
# 25737        20KM Walk  Silver  Guatemala  16342897.0  3903.47885604613
# 25738             400M    Gold    Grenada    106825.0  9212.02035173484
# 25739             800M  Silver   Botswana   2262485.0  6360.13822018837
# 25740            Laser  Silver     Cyprus   1165300.0  23242.8400685313
# 25741          + 80 KG  Silver      Gabon   1725292.0   8266.4456050624
#
#        Season
# 0      Winter
# 1      Winter
# 2      Winter
# 3      Winter
# 4      Winter
# ...       ...
# 25737  Summer
# 25738  Summer
# 25739  Summer
# 25740  Summer
# 25741  Summer
#
# [30568 rows x 13 columns]

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 2 items
#
# tests/test_all_df.py::TestAllDf::test_all_df_columns PASSED              [ 50%]
# tests/test_all_df.py::TestAllDf::test_all_df_shape PASSED                [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### Top Countries Analysis

# %%
top_10_df['Count'] = all_df[all_df['Year']>=1984].groupby('Country').count().sort_values(by='Year', ascending=False)

top_10_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yf/53d25rm10gq_l7wdtlp_205w0000gn/T/ipykernel_57285/685155000.py in <module>
# ----> 1 top_10_df['Count'] = all_df[all_df['Year']>=1984].groupby('Country').count().sort_values(by='Year', ascending=False)
#       2
#       3 top_10_df
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
top_10_df.rename(columns={"Year":"Medal Count"}, inplace=True)

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games',
    top_country_1=top_10_df.iloc[0]['Medal Count'],
    top_country_10=top_10_df.iloc[9]['Medal Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 1 item
#
# tests/test_olympic_games.py::TestOlympicGames::test_top_10_countries_medals PASSED [100%]
#
# ============================== 1 passed in 0.13s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games.pickle
#
# git commit -m 'Completed olympic_games step'
#
# git push origin master
