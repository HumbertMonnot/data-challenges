# %% [markdown]
# # API Data

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## On récupère la data

# %%
import requests

url = "https://iex.lewagon.com/stable/stock/aapl/chart/3m"
api_data = requests.get(url).json()

# %%
apple_df = pd.DataFrame(api_data)
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   close                 63 non-null     float64
#  1   high                  63 non-null     float64
#  2   low                   63 non-null     float64
#  3   open                  63 non-null     float64
#  4   symbol                63 non-null     object
#  5   volume                63 non-null     int64
#  6   id                    63 non-null     object
#  7   key                   63 non-null     object
#  8   subkey                63 non-null     object
#  9   date                  63 non-null     object
#  10  updated               63 non-null     int64
#  11  changeOverTime        63 non-null     float64
#  12  marketChangeOverTime  63 non-null     float64
#  13  uOpen                 63 non-null     float64
#  14  uClose                63 non-null     float64
#  15  uHigh                 63 non-null     float64
#  16  uLow                  63 non-null     float64
#  17  uVolume               63 non-null     int64
#  18  fOpen                 63 non-null     float64
#  19  fClose                63 non-null     float64
#  20  fHigh                 63 non-null     float64
#  21  fLow                  63 non-null     float64
#  22  fVolume               63 non-null     int64
#  23  label                 63 non-null     object
#  24  change                63 non-null     float64
#  25  changePercent         63 non-null     float64
# dtypes: float64(16), int64(4), object(6)
# memory usage: 12.9+ KB

# %%
apple_df['date'] = pd.to_datetime(apple_df['date'], format='%Y-%m-%d')

# %%
apple_df.set_index('date', inplace = True)

# %%
apple_df
# Out:
#              close      high     low     open symbol     volume  \
# date
# 2021-10-18  146.55  146.8400  143.16  143.445   AAPL   85589175
# 2021-10-19  148.76  149.1700  146.55  147.010   AAPL   76378894
# 2021-10-20  149.26  149.7539  148.12  148.700   AAPL   58418788
# 2021-10-21  149.48  149.6400  147.87  148.810   AAPL   61420990
# 2021-10-22  148.69  150.1800  148.64  149.690   AAPL   58883443
# ...            ...       ...     ...      ...    ...        ...
# 2022-01-10  172.19  172.5000  168.17  169.080   AAPL  106765552
# 2022-01-11  175.08  175.1800  170.82  172.320   AAPL   76138312
# 2022-01-12  175.53  177.1800  174.82  176.120   AAPL   74805173
# 2022-01-13  172.19  176.6200  171.79  175.780   AAPL   84505760
# 2022-01-14  173.07  173.7800  171.09  171.340   AAPL   80440780
#
#                            id   key subkey        updated  ...    uLow  \
# date                                                       ...
# 2021-10-18  HISTORICAL_PRICES  AAPL         1636136303000  ...  143.16
# 2021-10-19  HISTORICAL_PRICES  AAPL         1636136374000  ...  146.55
# 2021-10-20  HISTORICAL_PRICES  AAPL         1636136481000  ...  148.12
# 2021-10-21  HISTORICAL_PRICES  AAPL         1636136594000  ...  147.87
# 2021-10-22  HISTORICAL_PRICES  AAPL         1636136381000  ...  148.64
# ...                       ...   ...    ...            ...  ...     ...
# 2022-01-10  HISTORICAL_PRICES  AAPL         1641868221000  ...  168.17
# 2022-01-11  HISTORICAL_PRICES  AAPL         1641956415000  ...  170.82
# 2022-01-12  HISTORICAL_PRICES  AAPL         1642039220000  ...  174.82
# 2022-01-13  HISTORICAL_PRICES  AAPL         1642125614000  ...  171.79
# 2022-01-14  HISTORICAL_PRICES  AAPL         1642213828000  ...  171.09
#
#               uVolume     fOpen    fClose     fHigh      fLow    fVolume  \
# date
# 2021-10-18   85589175  143.2360  146.3364  146.6260  142.9514   85589175
# 2021-10-19   76378894  146.7958  148.5432  148.9526  146.3364   76378894
# 2021-10-20   58418788  148.4833  149.0425  149.5357  147.9041   58418788
# 2021-10-21   61420990  148.5931  149.2622  149.4219  147.6545   61420990
# 2021-10-22   58883443  149.4719  148.4733  149.9611  148.4234   58883443
# ...               ...       ...       ...       ...       ...        ...
# 2022-01-10  106765552  169.0800  172.1900  172.5000  168.1700  106765552
# 2022-01-11   76138312  172.3200  175.0800  175.1800  170.8200   76138312
# 2022-01-12   74805173  176.1200  175.5300  177.1800  174.8200   74805173
# 2022-01-13   84505760  175.7800  172.1900  176.6200  171.7900   84505760
# 2022-01-14   80440780  171.3400  173.0700  173.7800  171.0900   80440780
#
#                  label  change  changePercent
# date
# 2021-10-18  Oct 18, 21    0.00         0.0000
# 2021-10-19  Oct 19, 21    2.21         0.0151
# 2021-10-20  Oct 20, 21    0.50         0.0034
# 2021-10-21  Oct 21, 21    0.22         0.0015
# 2021-10-22  Oct 22, 21   -0.79        -0.0053
# ...                ...     ...            ...
# 2022-01-10  Jan 10, 22    0.02         0.0001
# 2022-01-11  Jan 11, 22    2.89         0.0168
# 2022-01-12  Jan 12, 22    0.45         0.0026
# 2022-01-13  Jan 13, 22   -3.34        -0.0190
# 2022-01-14  Jan 14, 22    0.88         0.0051
#
# [63 rows x 25 columns]

# %%
apple_filter_close_df = apple_df.filter(items = ['close','open', 'close', 'high', 'low'])
apple_filter_close_df.plot(figsize = (30,15))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from nbresult import ChallengeResult

result = ChallengeResult('apple',
    index_name=apple_df.index.name,
    index_type=apple_df.index.dtype,
    columns=apple_df.columns
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /Users/humbert/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/humbert/code/HumbertMonnot/data-challenges/02-Data-Toolkit/02-Data-Sourcing/01-Stock-Market-API
# plugins: anyio-3.4.0, dash-2.0.0
# collecting ... collected 3 items
#
# tests/test_apple.py::TestApple::test_apple_df_columns PASSED             [ 33%]
# tests/test_apple.py::TestApple::test_apple_df_index_is_timestamp PASSED  [ 66%]
# tests/test_apple.py::TestApple::test_apple_df_index_name_is_date PASSED  [100%]
#
# ============================== 3 passed in 0.38s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/apple.pickle
#
# git commit -m 'Completed apple step'
#
# git push origin master

# %% [markdown]
# What is the URL for the:
#
# Amazon stock prices since last year?
#
# Facebook market cap?
#
# Apple research and development spendings quarterly?
#
# Most recent news about Tesla?
#
# Performance of the ‘Energy’ sector?
